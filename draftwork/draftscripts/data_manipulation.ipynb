# %%
import csv

def sort_csv_by_author(input_csv, output_csv):
    with open(input_csv, mode='r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)
        rows = list(csv_reader)
        sorted_rows = sorted(rows, key=lambda row: row[1])

    with open(output_csv, mode='w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(header)
        csv_writer.writerows(sorted_rows)

    print(f"Sorted CSV saved as: {output_csv}")

if __name__ == "__main__":
    input_csv = 'books_metadata.csv'
    output_csv = 'books_metadata_sorted.csv'
    sort_csv_by_author(input_csv, output_csv)
# Out:
# Sorted CSV saved as: books_metadata_sorted.csv

# %%
import csv

def remove_empty_authors(input_csv, output_csv):
    cleaned_rows = []

    with open(input_csv, mode='r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)
        cleaned_rows.append(header)

        for row in csv_reader:
            if row[1].strip():
                cleaned_rows.append(row)

    with open(output_csv, mode='w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerows(cleaned_rows)

    print(f"Rows with empty 'Author' values have been removed. Cleaned CSV saved as: {output_csv}")

if __name__ == "__main__":
    input_csv = 'cleared.csv'
    output_csv = 'new.csv'
    remove_empty_authors(input_csv, output_csv)
# Out:
# Rows with empty 'Author' values have been removed. Cleaned CSV saved as: new.csv

# %%
import csv

def count_unique_authors(csv_filename):
    unique_authors = set()

    with open(csv_filename, mode='r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)

        for row in csv_reader:
            author_name = row[1].strip()
            if author_name:
                unique_authors.add(author_name)

    print(f"Number of unique authors: {len(unique_authors)}")

if __name__ == "__main__":
    csv_filename = "new.csv"
    count_unique_authors(csv_filename)
# Out:
# Number of unique authors: 488

# %%
import csv

def add_reference_column(input_csv, output_csv):
    updated_rows = []

    with open(input_csv, mode='r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)
        header.append('Reference')
        updated_rows.append(header)

        for row in csv_reader:
            author_name = row[1].strip()

            if author_name:
                reference = author_name.split()[0]
                reference = reference.replace(',', '')
            else:
                reference = 'Unknown'

            row.append(reference)
            updated_rows.append(row)

    with open(output_csv, mode='w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerows(updated_rows)

    print(f"Added 'Reference' column and removed all commas from it. Updated CSV saved as: {output_csv}")


if __name__ == "__main__":
    input_csv = 'reference2.csv'
    output_csv = 'final.csv'
    add_reference_column(input_csv, output_csv)
# Out:
# Added 'Reference' column and removed all commas from it. Updated CSV saved as: final.csv

# %%
import pandas as pd

def remove_self_references(input_csv, output_csv):
    df = pd.read_csv(input_csv)
    cleaned_df = df[df['author_of_book'] != df['full_author_referenced']]
    cleaned_df.to_csv(output_csv, index=False)
    print(f"Removed self-references. Cleaned data saved to {output_csv}")

if __name__ == "__main__":
    input_csv = 'references.csv'
    output_csv = 'references_cleaned.csv'
    remove_self_references(input_csv, output_csv)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Removed self-references. Cleaned data saved to references_cleaned.csv

# %%
import csv
import os
import re
import pandas as pd

def load_book_metadata(csv_file):
    book_metadata = {}
    with open(csv_file, mode='r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            index = row['Index']
            book_metadata[index] = {
                'filename': row['Filename'],
                'author_of_book': row['Author'],
                'birth_death': row['Birth - Death']
            }
    return book_metadata

def clean_context(text):
    return re.sub(r'\s+', ' ', text).strip()

def find_marx_references_with_context(book_text, book_filename, author_of_book, birth_death, context_size=100):
    snippets = []
    pattern = re.compile(r'\bmarx\b', re.IGNORECASE)

    for match in pattern.finditer(book_text):
        start, end = match.start(), match.end()

        before = clean_context(book_text[max(0, start - context_size):start])
        after = clean_context(book_text[end:end + context_size])

        snippet = before + book_text[start:end] + after

        snippets.append({
            'book_filename': book_filename,
            'author_of_book': author_of_book,
            'birth_death': birth_death,
            'reference': 'Marx',
            'context': snippet
        })

    return snippets

def process_books_for_marx(book_metadata, output_file, context_size=100):
    all_snippets = []

    for index, book_info in book_metadata.items():
        book_path = book_info['filename']

        if os.path.exists(book_path):
            print(f"Processing {book_path}...")

            with open(book_path, 'r', encoding='utf-8', errors='ignore') as f:
                book_text = f.read().lower()

                snippets = find_marx_references_with_context(
                    book_text, 
                    book_path, 
                    book_info['author_of_book'], 
                    book_info['birth_death'], 
                    context_size
                )

                if snippets:
                    print(f"Found {len(snippets)} Marx references in {book_path}")

                all_snippets.extend(snippets)

    if all_snippets:
        df = pd.DataFrame(all_snippets)
        with open(output_file, 'a', encoding='utf-8', newline='') as f:
            df.to_csv(f, header=f.tell() == 0, index=False)
        print(f"Appended Marx references to {output_file}")
    else:
        print("No Marx references found in any of the books.")

def main():
    csv_file = 'newest.csv'
    output_file = 'references_cleaned.csv'
    context_size = 100

    book_metadata = load_book_metadata(csv_file)

    process_books_for_marx(book_metadata, output_file, context_size)

if __name__ == "__main__":
    main()
# Out:
# Processing books/10.txt...
# Processing books/30.txt...
# Processing books/54.txt...
# Processing books/135.txt...
# Processing books/217.txt...
# Processing books/351.txt...
# Processing books/5.txt...
# Processing books/31.txt...
# Processing books/104.txt...
# Processing books/1758.txt...
# Processing books/2264.txt...
# Processing books/2326.txt...
# Processing books/2142.txt...
# Processing books/2307.txt...
# Processing books/571.txt...
# Processing books/214.txt...
# Processing books/289.txt...
# Processing books/315.txt...
# Processing books/412.txt...
# Processing books/1488.txt...
# Processing books/1199.txt...
# Processing books/2229.txt...
# Processing books/188.txt...
# Processing books/308.txt...
# Processing books/327.txt...
# Processing books/438.txt...
# Processing books/475.txt...
# Processing books/518.txt...
# Processing books/549.txt...
# Processing books/800.txt...
# Processing books/20.txt...
# Processing books/324.txt...
# Processing books/353.txt...
# Processing books/988.txt...
# Processing books/999.txt...
# Processing books/1096.txt...
# Processing books/1200.txt...
# Processing books/1435.txt...
# Processing books/1881.txt...
# Processing books/2295.txt...
# Processing books/1152.txt...
# Processing books/1857.txt...
# Processing books/498.txt...
# Processing books/939.txt...
# Processing books/1223.txt...
# Processing books/625.txt...
# Processing books/639.txt...
# Processing books/1690.txt...
# Processing books/1736.txt...
# Processing books/1945.txt...
# Processing books/1947.txt...
# Processing books/2145.txt...
# Processing books/2389.txt...
# Processing books/708.txt...
# Processing books/750.txt...
# Processing books/1057.txt...
# Processing books/1819.txt...
# Processing books/545.txt...
# Processing books/2296.txt...
# Processing books/193.txt...
# Processing books/50.txt...
# Processing books/1102.txt...
# Processing books/421.txt...
# Processing books/290.txt...
# Processing books/964.txt...
# Processing books/109.txt...
# Processing books/116.txt...
# Processing books/242.txt...
# Processing books/640.txt...
# Processing books/706.txt...
# Processing books/1812.txt...
# Processing books/842.txt...
# Processing books/1108.txt...
# Processing books/836.txt...
# Processing books/112.txt...
# Processing books/456.txt...
# Processing books/769.txt...
# Processing books/846.txt...
# Processing books/114.txt...
# Processing books/134.txt...
# Processing books/346.txt...
# Processing books/477.txt...
# Processing books/199.txt...
# Processing books/370.txt...
# Processing books/454.txt...
# Processing books/744.txt...
# Processing books/966.txt...
# Processing books/1576.txt...
# Processing books/1726.txt...
# Processing books/725.txt...
# Found 1 Marx references in books/725.txt
# Processing books/1300.txt...
# Found 1 Marx references in books/1300.txt
# Processing books/1707.txt...
# Processing books/2110.txt...
# Found 1 Marx references in books/2110.txt
# Processing books/1670.txt...
# Processing books/491.txt...
# Processing books/1556.txt...
# Processing books/2462.txt...
# Processing books/1409.txt...
# Processing books/376.txt...
# Processing books/587.txt...
# Processing books/1558.txt...
# Processing books/429.txt...
# Processing books/669.txt...
# Processing books/177.txt...
# Processing books/2499.txt...
# Processing books/32.txt...
# Processing books/231.txt...
# Processing books/530.txt...
# Processing books/588.txt...
# Processing books/1153.txt...
# Processing books/48.txt...
# Processing books/51.txt...
# Processing books/133.txt...
# Processing books/137.txt...
# Found 3 Marx references in books/137.txt
# Processing books/182.txt...
# Found 4 Marx references in books/182.txt
# Processing books/224.txt...
# Processing books/240.txt...
# Processing books/354.txt...
# Processing books/404.txt...
# Processing books/678.txt...
# Processing books/810.txt...
# Processing books/897.txt...
# Processing books/946.txt...
# Processing books/1316.txt...
# Found 3 Marx references in books/1316.txt
# Processing books/1416.txt...
# Processing books/2332.txt...
# Processing books/2007.txt...
# Processing books/906.txt...
# Processing books/853.txt...
# Processing books/878.txt...
# Found 1 Marx references in books/878.txt
# Processing books/36.txt...
# Processing books/1892.txt...
# Processing books/1394.txt...
# Processing books/1187.txt...
# Processing books/19.txt...
# Processing books/34.txt...
# Processing books/472.txt...
# Processing books/2449.txt...
# Processing books/27.txt...
# Found 2 Marx references in books/27.txt
# Processing books/1156.txt...
# Found 85 Marx references in books/1156.txt
# Processing books/1432.txt...
# Found 32 Marx references in books/1432.txt
# Processing books/33.txt...
# Processing books/303.txt...
# Processing books/359.txt...
# Processing books/470.txt...
# Processing books/288.txt...
# Processing books/879.txt...
# Processing books/1967.txt...
# Processing books/2020.txt...
# Found 1 Marx references in books/2020.txt
# Processing books/140.txt...
# Processing books/1028.txt...
# Processing books/781.txt...
# Processing books/1603.txt...
# Processing books/1004.txt...
# Processing books/1052.txt...
# Processing books/282.txt...
# Processing books/2206.txt...
# Processing books/731.txt...
# Processing books/937.txt...
# Processing books/1051.txt...
# Processing books/1163.txt...
# Processing books/72.txt...
# Processing books/144.txt...
# Processing books/218.txt...
# Processing books/443.txt...
# Processing books/446.txt...
# Processing books/509.txt...
# Processing books/531.txt...
# Processing books/557.txt...
# Processing books/598.txt...
# Processing books/659.txt...
# Processing books/732.txt...
# Processing books/742.txt...
# Processing books/760.txt...
# Processing books/772.txt...
# Processing books/843.txt...
# Processing books/902.txt...
# Processing books/903.txt...
# Processing books/1240.txt...
# Processing books/71.txt...
# Processing books/81.txt...
# Processing books/125.txt...
# Processing books/145.txt...
# Processing books/230.txt...
# Processing books/391.txt...
# Processing books/841.txt...
# Processing books/1291.txt...
# Processing books/1843.txt...
# Processing books/2383.txt...
# Processing books/1007.txt...
# Processing books/2439.txt...
# Processing books/1249.txt...
# Processing books/1355.txt...
# Processing books/1383.txt...
# Processing books/1528.txt...
# Processing books/1930.txt...
# Processing books/2503.txt...
# Processing books/816.txt...
# Processing books/2104.txt...
# Processing books/1196.txt...
# Processing books/1480.txt...
# Processing books/856.txt...
# Processing books/1620.txt...
# Processing books/1915.txt...
# Processing books/536.txt...
# Processing books/1061.txt...
# Processing books/705.txt...
# Processing books/1916.txt...
# Processing books/247.txt...
# Processing books/764.txt...
# Processing books/777.txt...
# Processing books/1003.txt...
# Processing books/2030.txt...
# Processing books/1738.txt...
# Processing books/1873.txt...
# Processing books/617.txt...
# Processing books/969.txt...
# Processing books/1137.txt...
# Processing books/1297.txt...
# Processing books/757.txt...
# Processing books/1398.txt...
# Processing books/2230.txt...
# Found 4 Marx references in books/2230.txt
# Processing books/815.txt...
# Processing books/1958.txt...
# Processing books/959.txt...
# Processing books/1482.txt...
# Processing books/1523.txt...
# Processing books/2357.txt...
# Processing books/2086.txt...
# Processing books/1264.txt...
# Processing books/1574.txt...
# Processing books/191.txt...
# Processing books/798.txt...
# Processing books/1562.txt...
# Processing books/1778.txt...
# Processing books/2062.txt...
# Processing books/2087.txt...
# Processing books/439.txt...
# Processing books/918.txt...
# Processing books/950.txt...
# Processing books/1050.txt...
# Processing books/1415.txt...
# Processing books/1518.txt...
# Processing books/1681.txt...
# Processing books/2233.txt...
# Processing books/95.txt...
# Processing books/278.txt...
# Processing books/1919.txt...
# Processing books/2271.txt...
# Processing books/2425.txt...
# Processing books/1810.txt...
# Found 11 Marx references in books/1810.txt
# Processing books/2000.txt...
# Found 1 Marx references in books/2000.txt
# Processing books/2163.txt...
# Processing books/540.txt...
# Processing books/721.txt...
# Processing books/730.txt...
# Processing books/837.txt...
# Processing books/1077.txt...
# Processing books/624.txt...
# Processing books/1964.txt...
# Processing books/1273.txt...
# Processing books/1539.txt...
# Processing books/1830.txt...
# Processing books/433.txt...
# Processing books/908.txt...
# Processing books/1520.txt...
# Processing books/1929.txt...
# Processing books/2248.txt...
# Processing books/1616.txt...
# Found 1 Marx references in books/1616.txt
# Processing books/393.txt...
# Processing books/2223.txt...
# Processing books/2130.txt...
# Processing books/961.txt...
# Processing books/770.txt...
# Processing books/872.txt...
# Processing books/1165.txt...
# Processing books/2473.txt...
# Processing books/1986.txt...
# Processing books/1274.txt...
# Processing books/2129.txt...
# Processing books/619.txt...
# Processing books/1893.txt...
# Processing books/1422.txt...
# Processing books/738.txt...
# Processing books/1853.txt...
# Processing books/818.txt...
# Processing books/213.txt...
# Processing books/285.txt...
# Processing books/548.txt...
# Processing books/630.txt...
# Processing books/637.txt...
# Processing books/674.txt...
# Found 1 Marx references in books/674.txt
# Processing books/1164.txt...
# Processing books/2025.txt...
# Processing books/2067.txt...
# Processing books/2281.txt...
# Processing books/255.txt...
# Processing books/2196.txt...
# Processing books/1626.txt...
# Processing books/1227.txt...
# Processing books/1696.txt...
# Processing books/23.txt...
# Processing books/561.txt...
# Processing books/1225.txt...
# Processing books/1122.txt...
# Processing books/2266.txt...
# Processing books/1537.txt...
# Processing books/2351.txt...
# Processing books/171.txt...
# Processing books/726.txt...
# Processing books/1267.txt...
# Processing books/1942.txt...
# Found 1 Marx references in books/1942.txt
# Processing books/2171.txt...
# Processing books/1115.txt...
# Processing books/1424.txt...
# Processing books/1804.txt...
# Processing books/1847.txt...
# Processing books/1882.txt...
# Processing books/1887.txt...
# Processing books/1913.txt...
# Processing books/2064.txt...
# Processing books/2088.txt...
# Processing books/2106.txt...
# Processing books/2108.txt...
# Processing books/2138.txt...
# Processing books/2167.txt...
# Processing books/2194.txt...
# Processing books/2195.txt...
# Processing books/2224.txt...
# Processing books/2226.txt...
# Processing books/2256.txt...
# Processing books/2257.txt...
# Processing books/2277.txt...
# Processing books/2363.txt...
# Processing books/2398.txt...
# Processing books/2420.txt...
# Processing books/2421.txt...
# Processing books/2443.txt...
# Processing books/2444.txt...
# Processing books/2476.txt...
# Processing books/2477.txt...
# Processing books/2494.txt...
# Processing books/1149.txt...
# Processing books/1219.txt...
# Processing books/1296.txt...
# Processing books/1428.txt...
# Processing books/2178.txt...
# Processing books/793.txt...
# Processing books/1841.txt...
# Processing books/1443.txt...
# Processing books/333.txt...
# Processing books/178.txt...
# Processing books/236.txt...
# Processing books/740.txt...
# Processing books/891.txt...
# Processing books/1025.txt...
# Processing books/1516.txt...
# Processing books/1649.txt...
# Processing books/1907.txt...
# Processing books/1820.txt...
# Processing books/1848.txt...
# Processing books/1665.txt...
# Processing books/2513.txt...
# Processing books/286.txt...
# Processing books/860.txt...
# Processing books/1097.txt...
# Processing books/1369.txt...
# Processing books/1384.txt...
# Processing books/1245.txt...
# Processing books/867.txt...
# Processing books/868.txt...
# Processing books/1376.txt...
# Processing books/268.txt...
# Processing books/1308.txt...
# Processing books/1655.txt...
# Processing books/2160.txt...
# Processing books/1073.txt...
# Processing books/18.txt...
# Processing books/57.txt...
# Processing books/76.txt...
# Processing books/83.txt...
# Processing books/565.txt...
# Processing books/1869.txt...
# Processing books/2070.txt...
# Processing books/2480.txt...
# Processing books/1575.txt...
# Processing books/2304.txt...
# Processing books/873.txt...
# Processing books/626.txt...
# Processing books/1181.txt...
# Processing books/2442.txt...
# Processing books/380.txt...
# Processing books/707.txt...
# Processing books/203.txt...
# Processing books/1303.txt...
# Processing books/1871.txt...
# Processing books/319.txt...
# Processing books/322.txt...
# Processing books/442.txt...
# Processing books/643.txt...
# Processing books/654.txt...
# Processing books/699.txt...
# Processing books/716.txt...
# Processing books/831.txt...
# Processing books/849.txt...
# Processing books/889.txt...
# Processing books/935.txt...
# Processing books/970.txt...
# Processing books/991.txt...
# Processing books/1049.txt...
# Processing books/1117.txt...
# Processing books/1226.txt...
# Processing books/1481.txt...
# Processing books/1557.txt...
# Processing books/1596.txt...
# Processing books/1729.txt...
# Processing books/1730.txt...
# Processing books/1824.txt...
# Processing books/1949.txt...
# Processing books/1950.txt...
# Processing books/2016.txt...
# Processing books/2026.txt...
# Processing books/2300.txt...
# Processing books/2219.txt...
# Processing books/91.txt...
# Processing books/722.txt...
# Processing books/473.txt...
# Processing books/1130.txt...
# Processing books/1628.txt...
# Processing books/128.txt...
# Processing books/263.txt...
# Processing books/387.txt...
# Processing books/13.txt...
# Processing books/29.txt...
# Processing books/67.txt...
# Processing books/93.txt...
# Processing books/105.txt...
# Processing books/115.txt...
# Processing books/270.txt...
# Processing books/898.txt...
# Processing books/1229.txt...
# Processing books/1927.txt...
# Processing books/2051.txt...
# Processing books/1992.txt...
# Processing books/130.txt...
# Processing books/1918.txt...
# Processing books/1618.txt...
# Processing books/233.txt...
# Processing books/1346.txt...
# Processing books/2031.txt...
# Processing books/795.txt...
# Processing books/345.txt...
# Processing books/2023.txt...
# Processing books/422.txt...
# Found 8 Marx references in books/422.txt
# Processing books/2353.txt...
# Processing books/1177.txt...
# Processing books/52.txt...
# Processing books/1434.txt...
# Found 39 Marx references in books/1434.txt
# Processing books/2010.txt...
# Processing books/2527.txt...
# Found 1 Marx references in books/2527.txt
# Processing books/1282.txt...
# Processing books/1496.txt...
# Processing books/733.txt...
# Processing books/1476.txt...
# Processing books/1765.txt...
# Processing books/753.txt...
# Processing books/1001.txt...
# Processing books/406.txt...
# Processing books/765.txt...
# Processing books/1333.txt...
# Processing books/1509.txt...
# Processing books/930.txt...
# Processing books/1060.txt...
# Processing books/1098.txt...
# Processing books/1105.txt...
# Processing books/1215.txt...
# Found 1 Marx references in books/1215.txt
# Processing books/1720.txt...
# Processing books/1242.txt...
# Processing books/1423.txt...
# Processing books/175.txt...
# Processing books/578.txt...
# Processing books/2114.txt...
# Processing books/700.txt...
# Processing books/1719.txt...
# Processing books/2158.txt...
# Processing books/1427.txt...
# Processing books/648.txt...
# Processing books/972.txt...
# Processing books/452.txt...
# Processing books/3.txt...
# Processing books/11.txt...
# Processing books/340.txt...
# Processing books/2407.txt...
# Processing books/544.txt...
# Found 1 Marx references in books/544.txt
# Processing books/667.txt...
# Processing books/1540.txt...
# Processing books/101.txt...
# Processing books/994.txt...
# Processing books/1453.txt...
# Processing books/1784.txt...
# Processing books/232.txt...
# Processing books/291.txt...
# Processing books/1578.txt...
# Processing books/554.txt...
# Processing books/680.txt...
# Processing books/916.txt...
# Processing books/952.txt...
# Processing books/1572.txt...
# Processing books/1862.txt...
# Processing books/1910.txt...
# Processing books/2063.txt...
# Processing books/844.txt...
# Processing books/1161.txt...
# Processing books/1371.txt...
# Processing books/2.txt...
# Processing books/164.txt...
# Processing books/210.txt...
# Processing books/1499.txt...
# Processing books/1704.txt...
# Processing books/1797.txt...
# Processing books/1863.txt...
# Processing books/1866.txt...
# Processing books/1883.txt...
# Processing books/1936.txt...
# Processing books/2019.txt...
# Processing books/2134.txt...
# Processing books/2430.txt...
# Processing books/569.txt...
# Processing books/845.txt...
# Processing books/1243.txt...
# Processing books/1405.txt...
# Processing books/1732.txt...
# Processing books/2287.txt...
# Processing books/1889.txt...
# Processing books/2221.txt...
# Processing books/657.txt...
# Processing books/650.txt...
# Processing books/1498.txt...
# Processing books/355.txt...
# Processing books/1573.txt...
# Processing books/2035.txt...
# Processing books/691.txt...
# Processing books/1315.txt...
# Processing books/1317.txt...
# Processing books/1359.txt...
# Processing books/1399.txt...
# Processing books/1470.txt...
# Processing books/1932.txt...
# Processing books/1939.txt...
# Processing books/2057.txt...
# Processing books/2305.txt...
# Processing books/2395.txt...
# Processing books/12.txt...
# Processing books/100.txt...
# Processing books/314.txt...
# Processing books/826.txt...
# Processing books/2331.txt...
# Processing books/632.txt...
# Processing books/2173.txt...
# Processing books/1054.txt...
# Processing books/1664.txt...
# Processing books/1965.txt...
# Processing books/526.txt...
# Processing books/2385.txt...
# Processing books/2441.txt...
# Processing books/2483.txt...
# Processing books/1178.txt...
# Processing books/1760.txt...
# Processing books/1917.txt...
# Processing books/2131.txt...
# Processing books/1740.txt...
# Processing books/495.txt...
# Found 2 Marx references in books/495.txt
# Processing books/1397.txt...
# Processing books/2053.txt...
# Processing books/2095.txt...
# Processing books/2038.txt...
# Processing books/2497.txt...
# Processing books/850.txt...
# Processing books/480.txt...
# Processing books/1129.txt...
# Processing books/2101.txt...
# Processing books/2141.txt...
# Found 3 Marx references in books/2141.txt
# Processing books/449.txt...
# Processing books/2001.txt...
# Processing books/675.txt...
# Found 4 Marx references in books/675.txt
# Processing books/1113.txt...
# Processing books/1769.txt...
# Processing books/629.txt...
# Processing books/2484.txt...
# Processing books/1984.txt...
# Found 1 Marx references in books/1984.txt
# Processing books/2186.txt...
# Processing books/298.txt...
# Processing books/1465.txt...
# Processing books/8.txt...
# Processing books/56.txt...
# Processing books/106.txt...
# Processing books/147.txt...
# Processing books/187.txt...
# Processing books/275.txt...
# Processing books/668.txt...
# Processing books/830.txt...
# Processing books/967.txt...
# Processing books/1284.txt...
# Processing books/1425.txt...
# Processing books/312.txt...
# Processing books/1363.txt...
# Processing books/813.txt...
# Processing books/1552.txt...
# Processing books/1604.txt...
# Processing books/1788.txt...
# Processing books/1955.txt...
# Processing books/2182.txt...
# Processing books/2241.txt...
# Processing books/2269.txt...
# Processing books/1352.txt...
# Processing books/1440.txt...
# Processing books/1747.txt...
# Processing books/2125.txt...
# Processing books/1999.txt...
# Processing books/1140.txt...
# Processing books/511.txt...
# Processing books/922.txt...
# Processing books/1900.txt...
# Processing books/876.txt...
# Processing books/244.txt...
# Processing books/4.txt...
# Processing books/7.txt...
# Processing books/15.txt...
# Processing books/17.txt...
# Processing books/28.txt...
# Processing books/38.txt...
# Processing books/46.txt...
# Processing books/53.txt...
# Processing books/64.txt...
# Processing books/89.txt...
# Processing books/96.txt...
# Processing books/102.txt...
# Processing books/154.txt...
# Processing books/225.txt...
# Processing books/238.txt...
# Processing books/302.txt...
# Processing books/311.txt...
# Processing books/325.txt...
# Processing books/326.txt...
# Processing books/341.txt...
# Processing books/384.txt...
# Processing books/420.txt...
# Processing books/527.txt...
# Processing books/641.txt...
# Processing books/656.txt...
# Processing books/763.txt...
# Processing books/788.txt...
# Processing books/1203.txt...
# Processing books/107.txt...
# Found 1 Marx references in books/107.txt
# Processing books/1864.txt...
# Processing books/451.txt...
# Processing books/307.txt...
# Processing books/1721.txt...
# Processing books/1109.txt...
# Processing books/1176.txt...
# Processing books/1395.txt...
# Processing books/1580.txt...
# Processing books/602.txt...
# Processing books/2105.txt...
# Processing books/120.txt...
# Processing books/719.txt...
# Processing books/980.txt...
# Processing books/1589.txt...
# Processing books/603.txt...
# Processing books/1248.txt...
# Processing books/1289.txt...
# Processing books/2004.txt...
# Processing books/2319.txt...
# Processing books/1612.txt...
# Processing books/1920.txt...
# Processing books/295.txt...
# Processing books/1676.txt...
# Processing books/2464.txt...
# Found 17 Marx references in books/2464.txt
# Processing books/1807.txt...
# Processing books/1506.txt...
# Processing books/942.txt...
# Processing books/14.txt...
# Processing books/595.txt...
# Processing books/1189.txt...
# Processing books/1484.txt...
# Processing books/1507.txt...
# Processing books/6.txt...
# Processing books/21.txt...
# Processing books/22.txt...
# Processing books/25.txt...
# Processing books/26.txt...
# Processing books/37.txt...
# Processing books/41.txt...
# Processing books/43.txt...
# Processing books/59.txt...
# Processing books/62.txt...
# Processing books/90.txt...
# Processing books/92.txt...
# Processing books/94.txt...
# Processing books/98.txt...
# Processing books/103.txt...
# Processing books/165.txt...
# Processing books/176.txt...
# Processing books/237.txt...
# Processing books/239.txt...
# Processing books/250.txt...
# Processing books/265.txt...
# Processing books/274.txt...
# Processing books/287.txt...
# Processing books/320.txt...
# Processing books/334.txt...
# Processing books/711.txt...
# Processing books/2416.txt...
# Processing books/162.txt...
# Processing books/462.txt...
# Processing books/1041.txt...
# Processing books/1258.txt...
# Processing books/276.txt...
# Processing books/606.txt...
# Processing books/832.txt...
# Processing books/895.txt...
# Processing books/1279.txt...
# Processing books/77.txt...
# Processing books/467.txt...
# Processing books/1205.txt...
# Processing books/1402.txt...
# Processing books/1599.txt...
# Processing books/1779.txt...
# Processing books/1914.txt...
# Processing books/917.txt...
# Processing books/400.txt...
# Processing books/2069.txt...
# Processing books/1474.txt...
# Processing books/1123.txt...
# Processing books/840.txt...
# Processing books/508.txt...
# Processing books/833.txt...
# Processing books/1261.txt...
# Processing books/864.txt...
# Processing books/2260.txt...
# Processing books/1092.txt...
# Processing books/1623.txt...
# Processing books/485.txt...
# Processing books/975.txt...
# Processing books/2301.txt...
# Processing books/907.txt...
# Processing books/1237.txt...
# Processing books/1429.txt...
# Processing books/1310.txt...
# Processing books/1320.txt...
# Processing books/2157.txt...
# Processing books/2036.txt...
# Found 1 Marx references in books/2036.txt
# Processing books/2510.txt...
# Processing books/1803.txt...
# Processing books/1983.txt...
# Processing books/2208.txt...
# Processing books/2267.txt...
# Processing books/108.txt...
# Processing books/2388.txt...
# Processing books/1017.txt...
# Processing books/212.txt...
# Processing books/281.txt...
# Processing books/445.txt...
# Processing books/464.txt...
# Processing books/471.txt...
# Processing books/829.txt...
# Processing books/1314.txt...
# Processing books/1332.txt...
# Processing books/1928.txt...
# Processing books/9.txt...
# Processing books/141.txt...
# Processing books/189.txt...
# Processing books/273.txt...
# Processing books/321.txt...
# Processing books/392.txt...
# Processing books/523.txt...
# Processing books/664.txt...
# Found 90 Marx references in books/664.txt
# Processing books/709.txt...
# Processing books/727.txt...
# Processing books/344.txt...
# Processing books/644.txt...
# Processing books/1238.txt...
# Processing books/1454.txt...
# Processing books/1529.txt...
# Processing books/1935.txt...
# Processing books/1906.txt...
# Processing books/1815.txt...
# Processing books/1767.txt...
# Processing books/2146.txt...
# Processing books/590.txt...
# Found 1 Marx references in books/590.txt
# Processing books/1513.txt...
# Processing books/2479.txt...
# Processing books/136.txt...
# Processing books/597.txt...
# Processing books/892.txt...
# Processing books/968.txt...
# Processing books/1089.txt...
# Processing books/1126.txt...
# Processing books/1412.txt...
# Processing books/1879.txt...
# Processing books/2078.txt...
# Processing books/982.txt...
# Found 1 Marx references in books/982.txt
# Processing books/279.txt...
# Processing books/181.txt...
# Processing books/801.txt...
# Processing books/920.txt...
# Processing books/2463.txt...
# Processing books/926.txt...
# Processing books/1330.txt...
# Processing books/1560.txt...
# Processing books/49.txt...
# Processing books/69.txt...
# Processing books/73.txt...
# Processing books/86.txt...
# Processing books/87.txt...
# Processing books/194.txt...
# Processing books/205.txt...
# Processing books/207.txt...
# Processing books/211.txt...
# Processing books/216.txt...
# Processing books/272.txt...
# Processing books/306.txt...
# Processing books/329.txt...
# Processing books/367.txt...
# Processing books/1492.txt...
# Processing books/1799.txt...
# Processing books/228.txt...
# Processing books/894.txt...
# Processing books/904.txt...
# Processing books/839.txt...
# Processing books/1641.txt...
# Processing books/2297.txt...
# Processing books/361.txt...
# Processing books/241.txt...
# Processing books/258.txt...
# Processing books/787.txt...
# Processing books/1132.txt...
# Processing books/292.txt...
# Processing books/533.txt...
# Processing books/1211.txt...
# Processing books/1592.txt...
# Processing books/1974.txt...
# Processing books/817.txt...
# Processing books/1611.txt...
# Processing books/1012.txt...
# Processing books/799.txt...
# Processing books/2311.txt...
# Found 2 Marx references in books/2311.txt
# Processing books/1377.txt...
# Processing books/677.txt...
# Processing books/697.txt...
# Processing books/871.txt...
# Processing books/963.txt...
# Processing books/1034.txt...
# Processing books/1168.txt...
# Processing books/1305.txt...
# Processing books/1306.txt...
# Processing books/1348.txt...
# Processing books/1349.txt...
# Processing books/1350.txt...
# Processing books/1430.txt...
# Processing books/1606.txt...
# Processing books/1625.txt...
# Processing books/1839.txt...
# Processing books/1957.txt...
# Processing books/173.txt...
# Processing books/139.txt...
# Processing books/1002.txt...
# Processing books/2179.txt...
# Processing books/1458.txt...
# Processing books/1874.txt...
# Processing books/2254.txt...
# Processing books/631.txt...
# Processing books/2320.txt...
# Processing books/1952.txt...
# Processing books/2356.txt...
# Processing books/1837.txt...
# Processing books/24.txt...
# Processing books/336.txt...
# Processing books/374.txt...
# Processing books/506.txt...
# Processing books/1103.txt...
# Processing books/1374.txt...
# Processing books/1375.txt...
# Processing books/1538.txt...
# Processing books/1636.txt...
# Processing books/2032.txt...
# Processing books/2033.txt...
# Processing books/2372.txt...
# Processing books/936.txt...
# Processing books/1216.txt...
# Processing books/1501.txt...
# Processing books/1582.txt...
# Processing books/1588.txt...
# Processing books/405.txt...
# Processing books/2321.txt...
# Processing books/618.txt...
# Processing books/923.txt...
# Processing books/1723.txt...
# Processing books/1328.txt...
# Processing books/2090.txt...
# Processing books/358.txt...
# Found 2 Marx references in books/358.txt
# Processing books/2285.txt...
# Processing books/1179.txt...
# Processing books/1235.txt...
# Processing books/1671.txt...
# Processing books/2460.txt...
# Processing books/1561.txt...
# Processing books/489.txt...
# Processing books/694.txt...
# Processing books/827.txt...
# Processing books/1167.txt...
# Processing books/1269.txt...
# Processing books/1445.txt...
# Processing books/1605.txt...
# Processing books/1894.txt...
# Processing books/1722.txt...
# Processing books/532.txt...
# Processing books/1461.txt...
# Processing books/253.txt...
# Processing books/819.txt...
# Processing books/783.txt...
# Processing books/2492.txt...
# Processing books/2412.txt...
# Processing books/1295.txt...
# Found 4 Marx references in books/1295.txt
# Processing books/2018.txt...
# Processing books/1032.txt...
# Processing books/901.txt...
# Processing books/1162.txt...
# Processing books/168.txt...
# Processing books/254.txt...
# Processing books/280.txt...
# Processing books/482.txt...
# Processing books/720.txt...
# Processing books/39.txt...
# Processing books/2472.txt...
# Processing books/2485.txt...
# Processing books/153.txt...
# Processing books/1764.txt...
# Processing books/2198.txt...
# Processing books/1347.txt...
# Processing books/1064.txt...
# Processing books/1995.txt...
# Processing books/535.txt...
# Processing books/2361.txt...
# Processing books/88.txt...
# Found 1 Marx references in books/88.txt
# Processing books/124.txt...
# Processing books/222.txt...
# Processing books/410.txt...
# Processing books/486.txt...
# Processing books/1246.txt...
# Found 1 Marx references in books/1246.txt
# Processing books/2034.txt...
# Processing books/42.txt...
# Processing books/992.txt...
# Processing books/689.txt...
# Processing books/775.txt...
# Processing books/855.txt...
# Processing books/1263.txt...
# Processing books/547.txt...
# Processing books/883.txt...
# Processing books/958.txt...
# Processing books/2118.txt...
# Processing books/2065.txt...
# Processing books/1644.txt...
# Processing books/1748.txt...
# Processing books/2306.txt...
# Processing books/444.txt...
# Processing books/2074.txt...
# Processing books/1159.txt...
# Processing books/1669.txt...
# Processing books/1673.txt...
# Processing books/1757.txt...
# Processing books/2324.txt...
# Processing books/2433.txt...
# Processing books/99.txt...
# Processing books/584.txt...
# Processing books/1147.txt...
# Processing books/1485.txt...
# Processing books/2048.txt...
# Processing books/735.txt...
# Processing books/1345.txt...
# Processing books/1365.txt...
# Processing books/1433.txt...
# Processing books/1904.txt...
# Processing books/2148.txt...
# Processing books/2288.txt...
# Processing books/2509.txt...
# Processing books/1944.txt...
# Processing books/2396.txt...
# Processing books/1510.txt...
# Processing books/1771.txt...
# Found 1 Marx references in books/1771.txt
# Processing books/2393.txt...
# Processing books/1711.txt...
# Processing books/1591.txt...
# Processing books/235.txt...
# Processing books/143.txt...
# Processing books/152.txt...
# Processing books/418.txt...
# Processing books/607.txt...
# Processing books/635.txt...
# Processing books/714.txt...
# Processing books/822.txt...
# Processing books/971.txt...
# Processing books/998.txt...
# Processing books/1020.txt...
# Processing books/1035.txt...
# Processing books/1116.txt...
# Processing books/1244.txt...
# Processing books/2242.txt...
# Processing books/2136.txt...
# Processing books/1400.txt...
# Found 11 Marx references in books/1400.txt
# Processing books/2344.txt...
# Processing books/2096.txt...
# Processing books/2392.txt...
# Processing books/2410.txt...
# Processing books/2451.txt...
# Processing books/2452.txt...
# Processing books/2488.txt...
# Processing books/2489.txt...
# Processing books/2504.txt...
# Processing books/2528.txt...
# Processing books/1362.txt...
# Processing books/2450.txt...
# Processing books/2523.txt...
# Processing books/347.txt...
# Processing books/2408.txt...
# Processing books/2360.txt...
# Processing books/954.txt...
# Processing books/1816.txt...
# Processing books/2006.txt...
# Processing books/2077.txt...
# Processing books/2436.txt...
# Processing books/1791.txt...
# Processing books/1908.txt...
# Processing books/2457.txt...
# Processing books/1503.txt...
# Processing books/1213.txt...
# Processing books/609.txt...
# Processing books/2137.txt...
# Processing books/1.txt...
# Processing books/35.txt...
# Processing books/55.txt...
# Processing books/200.txt...
# Processing books/881.txt...
# Processing books/2009.txt...
# Processing books/1631.txt...
# Processing books/808.txt...
# Processing books/2046.txt...
# Processing books/1233.txt...
# Processing books/2061.txt...
# Processing books/2151.txt...
# Processing books/2453.txt...
# Processing books/1674.txt...
# Found 1 Marx references in books/1674.txt
# Processing books/158.txt...
# Processing books/267.txt...
# Processing books/294.txt...
# Processing books/413.txt...
# Processing books/1976.txt...
# Processing books/84.txt...
# Processing books/1121.txt...
# Processing books/2097.txt...
# Processing books/885.txt...
# Processing books/1204.txt...
# Processing books/1056.txt...
# Processing books/1174.txt...
# Processing books/1231.txt...
# Processing books/1232.txt...
# Processing books/1271.txt...
# Processing books/1381.txt...
# Processing books/1447.txt...
# Processing books/1473.txt...
# Processing books/1550.txt...
# Processing books/1569.txt...
# Processing books/1570.txt...
# Processing books/1642.txt...
# Processing books/1897.txt...
# Appended Marx references to references_cleaned.csv

# %%
import csv
import re
import pandas as pd

def load_author_list(csv_file):
    authors_to_reference = []
    with open(csv_file, mode='r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            author = row['Author']
            authors_to_reference.append(author)
    return list(set(authors_to_reference))

def clean_context(text):
    return re.sub(r'\s+', ' ', text).strip()

def find_references_in_manifesto(book_text, authors, context_size=100):
    snippets = []
    pattern = re.compile(r'\b(' + '|'.join(map(re.escape, authors)) + r')\b', re.IGNORECASE)

    for match in pattern.finditer(book_text):
        start, end = match.start(), match.end()
        referenced_author = match.group()

        before = clean_context(book_text[max(0, start - context_size):start])
        after = clean_context(book_text[end:end + context_size])

        snippet = before + book_text[start:end] + after

        snippets.append({
            'book_filename': '27.txt',
            'author_of_book': 'Marx',
            'birth_death': '1818 - 1883',
            'reference': referenced_author,
            'context': snippet
        })

    return snippets

def process_manifesto_references(csv_file, book_path, output_file, context_size=100):
    authors_to_reference = load_author_list(csv_file)

    if not os.path.exists(book_path):
        print(f"{book_path} not found.")
        return

    with open(book_path, 'r', encoding='utf-8', errors='ignore') as f:
        book_text = f.read().lower()

        snippets = find_references_in_manifesto(book_text, authors_to_reference, context_size)

        if snippets:
            df = pd.DataFrame(snippets)
            with open(output_file, 'a', encoding='utf-8', newline='') as f:
                df.to_csv(f, header=f.tell() == 0, index=False)
            print(f"Appended references from Marx to other authors in {output_file}")
        else:
            print("No references from Marx to other authors found in 27.txt.")

def main():
    csv_file = 'newest.csv'
    book_path = 'books/27.txt'
    output_file = 'references_cleaned.csv'
    context_size = 100

    process_manifesto_references(csv_file, book_path, output_file, context_size)

if __name__ == "__main__":
    main()
# Out:
# Appended references from Marx to other authors in references_cleaned.csv

# %%
import pandas as pd

def remove_specific_author(input_csv, output_csv, author_to_remove):
    df = pd.read_csv(input_csv)
    cleaned_df = df[(df['author_of_book'] != author_to_remove) & (df['full_author_referenced'] != author_to_remove)]

    cleaned_df.to_csv(output_csv, index=False)
    print(f"Removed rows where '{author_to_remove}' is the author or the referenced author. Cleaned data saved to {output_csv}")

if __name__ == "__main__":
    input_csv = 'references.csv'
    output_csv = 'reference2.csv'
    author_to_remove = 'Plato (spurious and doubtful works)'
    remove_specific_author(input_csv, output_csv, author_to_remove)
# Out:
# Removed rows where 'Plato (spurious and doubtful works)' is the author or the referenced author. Cleaned data saved to reference2.csv

# %%
import pandas as pd

input_file = 'reference2.csv'
df = pd.read_csv(input_file)
df_no_self_references = df[df['author_of_book'] != df['full_author_referenced']]
output_file = 'updated_references.csv'  # Path for the updated CSV file
df_no_self_references.to_csv(output_file, index=False)

print(f"Updated CSV file without self-references saved as '{output_file}'")
# Out:
# Updated CSV file without self-references saved as 'updated_references.csv'

# %%
import pandas as pd
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer

def analyze_topics(input_file, sample_size=5000):
    df = pd.read_csv(input_file)
    df_sample = df.head(sample_size)
    
    embedding_model = SentenceTransformer('all-mpnet-base-v2')
    
    vectorizer_model = CountVectorizer(
        stop_words="english", 
        min_df=2,
        ngram_range=(1, 2)
    )
    
    topic_model = BERTopic(
        embedding_model=embedding_model,
        vectorizer_model=vectorizer_model,
        min_topic_size=5,
        verbose=True
    )
    
    topics, probs = topic_model.fit_transform(df_sample['context'].tolist())
    
    topic_info = topic_model.get_document_info(df_sample['context'].tolist())
    
    df_with_topics = df_sample.copy()
    df_with_topics['Topic'] = topics
    df_with_topics['Topic_Name'] = topic_info['Name']
    df_with_topics['Topic_Probability'] = probs
    
    topic_labels = {}
    for topic in set(topics):
        if topic != -1:
            topic_terms = topic_model.get_topic(topic)
            label = ', '.join([term[0] for term in topic_terms[:3]])
            topic_labels[topic] = label
    
    df_with_topics['Topic_Terms'] = df_with_topics['Topic'].map(
        lambda x: topic_labels.get(x, 'Outlier'))
    
    output_file = 'output_with_topics_4.csv'
    df_with_topics.to_csv(output_file, index=False)
    
    print(f"\nProcessed {len(df_sample)} documents")
    print(f"Found {len(set(topics))} topics (excluding outliers)")
    print(f"Results saved to {output_file}")
    
    return df_with_topics

input_file = "references.csv"
results = analyze_topics(input_file, sample_size=5000)

display(results.head())
# Out:
# 2024-10-27 15:19:54,858 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]
# 2024-10-27 15:22:36,757 - BERTopic - Embedding - Completed ✓
# 2024-10-27 15:22:36,761 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 2024-10-27 15:22:48,306 - BERTopic - Dimensionality - Completed ✓
# 2024-10-27 15:22:48,308 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-10-27 15:22:48,425 - BERTopic - Cluster - Completed ✓
# 2024-10-27 15:22:48,436 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-10-27 15:22:48,785 - BERTopic - Representation - Completed ✓
# Processed 5000 documents
# Found 229 topics (excluding outliers)
# Results saved to output_with_topics_4.csv
#     book_filename author_of_book  birth_death  reference  \
# 0  books/1223.txt       Buchanan  1804 - 1870  aristotle
# 1  books/1223.txt       Buchanan  1804 - 1870  augustine
# 2  books/1223.txt       Buchanan  1804 - 1870   berkeley
# 3  books/1223.txt       Buchanan  1804 - 1870   berkeley
# 4  books/1223.txt       Buchanan  1804 - 1870   berkeley
#
#   full_author_referenced                                            context  \
# 0              Aristotle  l its laws and processes, its tribes and races...
# 1              Augustine  oth, 25 cts. philip doddridge. his life and la...
# 2               Berkeley  every man's reason, therefore, is really god; ...
# 3               Berkeley  nd "object" of thought are the same? or, wheth...
# 4               Berkeley  existence of unthinking things without any rel...
#
#    Topic                                         Topic_Name  \
# 0     48  48_eternal_existent_self existent_existent ete...
# 1    205                      205_cloth_tweedie_works_cents
# 2    163       163_personality_mere_self consciousness_self
# 3     -1                    -1_footnote_god_philosophy_life
# 4     -1                    -1_footnote_god_philosophy_life
#
#    Topic_Probability                            Topic_Terms
# 0           0.369623       eternal, existent, self existent
# 1           1.000000                  cloth, tweedie, works
# 2           0.932810  personality, mere, self consciousness
# 3           0.000000                                Outlier
# 4           0.000000                                Outlier

# %%
from transformers import pipeline
import pandas as pd
from tqdm.notebook import tqdm
from datetime import datetime
import time

def process_large_dataset(df, categories, batch_size=10, total_samples=None):
    if total_samples is None:
        total_samples = len(df)

    print(f"Starting classification of {total_samples} samples at {datetime.now().strftime('%H:%M:%S')}")

    all_predictions = []
    all_confidences = []
    error_count = 0
    start_time = time.time()

    df_subset = df.head(total_samples).copy()
    
    for i in tqdm(range(0, len(df_subset), batch_size), desc="Processing batches"):
        batch_start_time = time.time()

        batch_texts = df_subset['context'].iloc[i:i+batch_size]

        try:
            classifier = pipeline(
                "zero-shot-classification",
                model="cross-encoder/nli-distilroberta-base",
                device=-1
            )

            batch_predictions = []
            batch_confidences = []

            for text in batch_texts:
                try:
                    truncated_text = text[:128] if isinstance(text, str) else ""

                    if not truncated_text:
                        batch_predictions.append("unknown")
                        batch_confidences.append(0.0)
                        continue

                    result = classifier(
                        truncated_text,
                        candidate_labels=categories
                    )
                    batch_predictions.append(result['labels'][0])
                    batch_confidences.append(round(result['scores'][0], 3))

                except Exception as e:
                    print(f"Error processing individual text: {str(e)}")
                    batch_predictions.append("error")
                    batch_confidences.append(0.0)
                    error_count += 1

            all_predictions.extend(batch_predictions)
            all_confidences.extend(batch_confidences)

            del classifier

            batch_time = time.time() - batch_start_time
            if (i / batch_size) % 5 == 0:
                print(f"\nBatch {i // batch_size + 1} processed in {batch_time:.1f} seconds")
                print(f"Current error rate: {(error_count / len(all_predictions)) * 100:.1f}%")

            if (i + batch_size) % 1000 == 0 or i + batch_size >= len(df_subset):
                temp_df = df_subset.iloc[:len(all_predictions)].copy()
                temp_df['predicted_category'] = all_predictions
                temp_df['confidence'] = all_confidences
                temp_df.to_csv(f"intermediate_results_{len(all_predictions)}.csv", index=False)
                print(f"Intermediate results saved at {len(all_predictions)} samples")

        except Exception as e:
            print(f"\nError processing batch starting at index {i}: {str(e)}")
            all_predictions.extend(["error"] * len(batch_texts))
            all_confidences.extend([0.0] * len(batch_texts))
            error_count += len(batch_texts)

    df_results = df_subset.iloc[:len(all_predictions)].copy()
    df_results['predicted_category'] = all_predictions
    df_results['confidence'] = all_confidences

    total_time = time.time() - start_time
    print("\n=== Classification Complete ===")
    print(f"Total processing time: {total_time / 60:.1f} minutes")
    print(f"Average time per sample: {total_time / len(df_results):.2f} seconds")
    print(f"Total errors: {error_count} ({(error_count / len(df_results)) * 100:.1f}%)")
    print("\nCategory Distribution:")
    print(df_results['predicted_category'].value_counts())
    print("\nConfidence Statistics:")
    print(df_results['confidence'].describe())

    return df_results

df = pd.read_csv('final.csv')

results_df = process_large_dataset(
    df, 
    categories,
    batch_size=10,
    total_samples=len(df)
)

results_df.to_csv('philosophy_classifications_full.csv', index=False)

print("All samples processed and results saved to 'philosophy_classifications_full.csv'.")
# Out:
# Starting classification of 109691 samples at 21:57:51
# Processing batches:   0%|          | 0/10970 [00:00<?, ?it/s]
# Batch 1 processed in 2.5 seconds
# Current error rate: 0.0%
#
# Batch 6 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 11 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 16 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 21 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 26 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 31 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 36 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 41 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 46 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 51 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 56 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 61 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 66 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 71 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 76 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 81 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 86 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 91 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 96 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 1000 samples
#
# Batch 101 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 106 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 111 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 116 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 121 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 126 processed in 3.6 seconds
# Current error rate: 0.0%
#
# Batch 131 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 136 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 141 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 146 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 151 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 156 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 161 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 166 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 171 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 176 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 181 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 186 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 191 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 196 processed in 1.8 seconds
# Current error rate: 0.0%
# Intermediate results saved at 2000 samples
#
# Batch 201 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 206 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 211 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 216 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 221 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 226 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 231 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 236 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 241 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 246 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 251 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 256 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 261 processed in 2.7 seconds
# Current error rate: 0.0%
#
# Batch 266 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 271 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 276 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 281 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 286 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 291 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 296 processed in 2.0 seconds
# Current error rate: 0.0%
# Intermediate results saved at 3000 samples
#
# Batch 301 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 306 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 311 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 316 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 321 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 326 processed in 2.5 seconds
# Current error rate: 0.0%
#
# Batch 331 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 336 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 341 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 346 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 351 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 356 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 361 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 366 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 371 processed in 3.0 seconds
# Current error rate: 0.0%
#
# Batch 376 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 381 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 386 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 391 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 396 processed in 1.5 seconds
# Current error rate: 0.0%
# Intermediate results saved at 4000 samples
#
# Batch 401 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 406 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 411 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 416 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 421 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 426 processed in 2.9 seconds
# Current error rate: 0.0%
#
# Batch 431 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 436 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 441 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 446 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 451 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 456 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 461 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 466 processed in 2.3 seconds
# Current error rate: 0.0%
#
# Batch 471 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 476 processed in 2.5 seconds
# Current error rate: 0.0%
#
# Batch 481 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 486 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 491 processed in 4.8 seconds
# Current error rate: 0.0%
#
# Batch 496 processed in 1.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 5000 samples
#
# Batch 501 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 506 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 511 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 516 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 521 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 526 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 531 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 536 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 541 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 546 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 551 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 556 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 561 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 566 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 571 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 576 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 581 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 586 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 591 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 596 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 6000 samples
#
# Batch 601 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 606 processed in 2.2 seconds
# Current error rate: 0.0%
#
# Batch 611 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 616 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 621 processed in 2.4 seconds
# Current error rate: 0.0%
#
# Batch 626 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 631 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 636 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 641 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 646 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 651 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 656 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 661 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 666 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 671 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 676 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 681 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 686 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 691 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 696 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 7000 samples
#
# Batch 701 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 706 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 711 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 716 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 721 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 726 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 731 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 736 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 741 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 746 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 751 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 756 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 761 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 766 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 771 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 776 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 781 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 786 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 791 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 796 processed in 1.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 8000 samples
#
# Batch 801 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 806 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 811 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 816 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 821 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 826 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 831 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 836 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 841 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 846 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 851 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 856 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 861 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 866 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 871 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 876 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 881 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 886 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 891 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 896 processed in 1.5 seconds
# Current error rate: 0.0%
# Intermediate results saved at 9000 samples
#
# Batch 901 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 906 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 911 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 916 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 921 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 926 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 931 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 936 processed in 2.8 seconds
# Current error rate: 0.0%
#
# Batch 941 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 946 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 951 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 956 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 961 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 966 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 971 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 976 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 981 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 986 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 991 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 996 processed in 1.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 10000 samples
#
# Batch 1001 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1006 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1011 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1016 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1021 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 1026 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1031 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1036 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1041 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1046 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1051 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1056 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1061 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1066 processed in 3.5 seconds
# Current error rate: 0.0%
#
# Batch 1071 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1076 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1081 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1086 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1091 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1096 processed in 2.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 11000 samples
#
# Batch 1101 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 1106 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1111 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 1116 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 1121 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1126 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1131 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1136 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1141 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1146 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1151 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1156 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1161 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1166 processed in 3.1 seconds
# Current error rate: 0.0%
#
# Batch 1171 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1176 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1181 processed in 3.0 seconds
# Current error rate: 0.0%
#
# Batch 1186 processed in 2.2 seconds
# Current error rate: 0.0%
#
# Batch 1191 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1196 processed in 1.5 seconds
# Current error rate: 0.0%
# Intermediate results saved at 12000 samples
#
# Batch 1201 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1206 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1211 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1216 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1221 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1226 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1231 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1236 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1241 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1246 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1251 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1256 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1261 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1266 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1271 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 1276 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1281 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1286 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1291 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1296 processed in 2.2 seconds
# Current error rate: 0.0%
# Intermediate results saved at 13000 samples
#
# Batch 1301 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1306 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1311 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1316 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1321 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1326 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1331 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1336 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1341 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1346 processed in 2.3 seconds
# Current error rate: 0.0%
#
# Batch 1351 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1356 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1361 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1366 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1371 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1376 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1381 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1386 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1391 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1396 processed in 1.8 seconds
# Current error rate: 0.0%
# Intermediate results saved at 14000 samples
#
# Batch 1401 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1406 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 1411 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1416 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 1421 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1426 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1431 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1436 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1441 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1446 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1451 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1456 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1461 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1466 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1471 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1476 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1481 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1486 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1491 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1496 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 15000 samples
#
# Batch 1501 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 1506 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1511 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1516 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1521 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1526 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1531 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1536 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1541 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1546 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1551 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1556 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1561 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1566 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1571 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1576 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1581 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1586 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1591 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1596 processed in 1.5 seconds
# Current error rate: 0.0%
# Intermediate results saved at 16000 samples
#
# Batch 1601 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1606 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1611 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1616 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1621 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1626 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1631 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1636 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1641 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1646 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1651 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1656 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1661 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1666 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1671 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1676 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1681 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1686 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1691 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1696 processed in 1.5 seconds
# Current error rate: 0.0%
# Intermediate results saved at 17000 samples
#
# Batch 1701 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1706 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1711 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1716 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1721 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1726 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1731 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1736 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1741 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1746 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1751 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 1756 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1761 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1766 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1771 processed in 2.2 seconds
# Current error rate: 0.0%
#
# Batch 1776 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1781 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1786 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1791 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1796 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 18000 samples
#
# Batch 1801 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1806 processed in 2.3 seconds
# Current error rate: 0.0%
#
# Batch 1811 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 1816 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 1821 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1826 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1831 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1836 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1841 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1846 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 1851 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1856 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1861 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1866 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 1871 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1876 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1881 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1886 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1891 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1896 processed in 1.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 19000 samples
#
# Batch 1901 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1906 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1911 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1916 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1921 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1926 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1931 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1936 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1941 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1946 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1951 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1956 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 1961 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1966 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 1971 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1976 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 1981 processed in 2.2 seconds
# Current error rate: 0.0%
#
# Batch 1986 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 1991 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 1996 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 20000 samples
#
# Batch 2001 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 2006 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2011 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2016 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2021 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2026 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2031 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2036 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2041 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2046 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2051 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2056 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2061 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2066 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2071 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2076 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2081 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2086 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2091 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2096 processed in 1.5 seconds
# Current error rate: 0.0%
# Intermediate results saved at 21000 samples
#
# Batch 2101 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2106 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2111 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2116 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2121 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2126 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2131 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2136 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2141 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 2146 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 2151 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2156 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2161 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2166 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2171 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2176 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2181 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2186 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2191 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2196 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 22000 samples
#
# Batch 2201 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2206 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2211 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2216 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2221 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2226 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2231 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2236 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2241 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2246 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2251 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2256 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2261 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2266 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2271 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2276 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2281 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2286 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2291 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2296 processed in 1.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 23000 samples
#
# Batch 2301 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2306 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2311 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2316 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2321 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2326 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2331 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2336 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2341 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2346 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2351 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2356 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2361 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2366 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2371 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2376 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2381 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2386 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 2391 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2396 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 24000 samples
#
# Batch 2401 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2406 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2411 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2416 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2421 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 2426 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2431 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2436 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2441 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2446 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2451 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2456 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2461 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2466 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2471 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2476 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2481 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2486 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 2491 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2496 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 25000 samples
#
# Batch 2501 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2506 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2511 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2516 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2521 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2526 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2531 processed in 2.4 seconds
# Current error rate: 0.0%
#
# Batch 2536 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2541 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2546 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 2551 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2556 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2561 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2566 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2571 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2576 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2581 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2586 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2591 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2596 processed in 2.1 seconds
# Current error rate: 0.0%
# Intermediate results saved at 26000 samples
#
# Batch 2601 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 2606 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 2611 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2616 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2621 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2626 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2631 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2636 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2641 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2646 processed in 2.2 seconds
# Current error rate: 0.0%
#
# Batch 2651 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2656 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2661 processed in 4.9 seconds
# Current error rate: 0.0%
#
# Batch 2666 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2671 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2676 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 2681 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2686 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2691 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2696 processed in 1.5 seconds
# Current error rate: 0.0%
# Intermediate results saved at 27000 samples
#
# Batch 2701 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2706 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2711 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2716 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2721 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2726 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 2731 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2736 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2741 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2746 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2751 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2756 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2761 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 2766 processed in 2.9 seconds
# Current error rate: 0.0%
#
# Batch 2771 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2776 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2781 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2786 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2791 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2796 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 28000 samples
#
# Batch 2801 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2806 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2811 processed in 2.4 seconds
# Current error rate: 0.0%
#
# Batch 2816 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2821 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 2826 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2831 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2836 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 2841 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2846 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2851 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 2856 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2861 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2866 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2871 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2876 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2881 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2886 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2891 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2896 processed in 1.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 29000 samples
#
# Batch 2901 processed in 2.3 seconds
# Current error rate: 0.0%
#
# Batch 2906 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2911 processed in 2.3 seconds
# Current error rate: 0.0%
#
# Batch 2916 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2921 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2926 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 2931 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 2936 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 2941 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2946 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2951 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2956 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2961 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 2966 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2971 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 2976 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2981 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2986 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 2991 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 2996 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 30000 samples
#
# Batch 3001 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3006 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3011 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3016 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3021 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3026 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3031 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3036 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3041 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3046 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3051 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3056 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 3061 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3066 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3071 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3076 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3081 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3086 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3091 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3096 processed in 1.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 31000 samples
#
# Batch 3101 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3106 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3111 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3116 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3121 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3126 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3131 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3136 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3141 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3146 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3151 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3156 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3161 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3166 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3171 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3176 processed in 2.3 seconds
# Current error rate: 0.0%
#
# Batch 3181 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3186 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 3191 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3196 processed in 1.7 seconds
# Current error rate: 0.0%
# Intermediate results saved at 32000 samples
#
# Batch 3201 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3206 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3211 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3216 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3221 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3226 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3231 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3236 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 3241 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3246 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 3251 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3256 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3261 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3266 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3271 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3276 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3281 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3286 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3291 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3296 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 33000 samples
#
# Batch 3301 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3306 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3311 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3316 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3321 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3326 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3331 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3336 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3341 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 3346 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3351 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3356 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3361 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3366 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 3371 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 3376 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3381 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3386 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3391 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3396 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 34000 samples
#
# Batch 3401 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3406 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3411 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3416 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3421 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3426 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3431 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3436 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3441 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3446 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3451 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3456 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3461 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3466 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3471 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3476 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3481 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3486 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3491 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3496 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 35000 samples
#
# Batch 3501 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3506 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3511 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3516 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3521 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3526 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3531 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3536 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3541 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3546 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3551 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3556 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3561 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3566 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3571 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3576 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3581 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3586 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3591 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3596 processed in 1.8 seconds
# Current error rate: 0.0%
# Intermediate results saved at 36000 samples
#
# Batch 3601 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3606 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3611 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3616 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3621 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3626 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3631 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3636 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3641 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3646 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3651 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3656 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3661 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3666 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3671 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 3676 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3681 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3686 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3691 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3696 processed in 1.6 seconds
# Current error rate: 0.0%
# Intermediate results saved at 37000 samples
#
# Batch 3701 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 3706 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 3711 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 3716 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3721 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 3726 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3731 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 3736 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 3741 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 3746 processed in 1.5 seconds
# ...
# Current error rate: 0.0%
#
# Batch 10021 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10026 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10031 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10036 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10041 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10046 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 10051 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 10056 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10061 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10066 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10071 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10076 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10081 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10086 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10091 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10096 processed in 1.5 seconds
# Current error rate: 0.0%
# Intermediate results saved at 101010 samples
#
# Batch 10101 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10106 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10111 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10116 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 10121 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10126 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10131 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10136 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10141 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10146 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10151 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10156 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10161 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10166 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10171 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10176 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10181 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 10186 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10191 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10196 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Error processing batch starting at index 101990: [Errno 28] No space left on device: 'intermediate_results_102010.csv'
#
# Batch 10201 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10206 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10211 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10216 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10221 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10226 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10231 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10236 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10241 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10246 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10251 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10256 processed in 1.4 seconds
# Current error rate: 0.0%
#
# Batch 10261 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10266 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10271 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10276 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10281 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10286 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10291 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10296 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Error processing batch starting at index 102990: [Errno 28] No space left on device: 'intermediate_results_103020.csv'
#
# Batch 10301 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10306 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10311 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 10316 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10321 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10326 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10331 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 10336 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10341 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 10346 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10351 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10356 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10361 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10366 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10371 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10376 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10381 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10386 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10391 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10396 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Error processing batch starting at index 103990: [Errno 28] No space left on device: 'intermediate_results_104030.csv'
#
# Batch 10401 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10406 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10411 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 10416 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10421 processed in 1.9 seconds
# Current error rate: 0.0%
#
# Batch 10426 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10431 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10436 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10441 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10446 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10451 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10456 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10461 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10466 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 10471 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10476 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10481 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 10486 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 10491 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 10496 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Error processing batch starting at index 104990: [Errno 28] No space left on device: 'intermediate_results_105040.csv'
#
# Batch 10501 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10506 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10511 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10516 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10521 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10526 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10531 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10536 processed in 2.1 seconds
# Current error rate: 0.0%
#
# Batch 10541 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10546 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10551 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10556 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10561 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10566 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10571 processed in 1.5 seconds
# Current error rate: 0.0%
#
# Batch 10576 processed in 2.0 seconds
# Current error rate: 0.0%
#
# Batch 10581 processed in 1.6 seconds
# Current error rate: 0.0%
#
# Batch 10586 processed in 1.7 seconds
# Current error rate: 0.0%
#
# Batch 10591 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Batch 10596 processed in 1.8 seconds
# Current error rate: 0.0%
#
# Error processing batch starting at index 105990: [Errno 28] No space left on device: 'intermediate_results_106050.csv'
#
# Batch 10601 processed in 1.6 seconds
# Current error rate: 0.1%
#
# Batch 10606 processed in 1.8 seconds
# Current error rate: 0.1%
#
# Batch 10611 processed in 1.9 seconds
# Current error rate: 0.1%
#
# Batch 10616 processed in 1.7 seconds
# Current error rate: 0.1%
#
# Batch 10621 processed in 1.6 seconds
# Current error rate: 0.1%
#
# Batch 10626 processed in 1.7 seconds
# Current error rate: 0.1%
#
# Batch 10631 processed in 1.6 seconds
# Current error rate: 0.1%
#
# Batch 10636 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10641 processed in 1.7 seconds
# Current error rate: 0.1%
#
# Batch 10646 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10651 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10656 processed in 1.7 seconds
# Current error rate: 0.1%
#
# Batch 10661 processed in 1.8 seconds
# Current error rate: 0.1%
#
# Batch 10666 processed in 1.6 seconds
# Current error rate: 0.1%
#
# Batch 10671 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10676 processed in 1.6 seconds
# Current error rate: 0.1%
#
# Batch 10681 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10686 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10691 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10696 processed in 1.8 seconds
# Current error rate: 0.1%
# Intermediate results saved at 107060 samples
#
# Batch 10701 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10706 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10711 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10716 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10721 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10726 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10731 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10736 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10741 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10746 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10751 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10756 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10761 processed in 1.8 seconds
# Current error rate: 0.1%
#
# Batch 10766 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10771 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10776 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10781 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10786 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10791 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10796 processed in 1.5 seconds
# Current error rate: 0.1%
# Intermediate results saved at 108060 samples
#
# Batch 10801 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10806 processed in 1.8 seconds
# Current error rate: 0.1%
#
# Batch 10811 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10816 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10821 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10826 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10831 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10836 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10841 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10846 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10851 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10856 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10861 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10866 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10871 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10876 processed in 1.8 seconds
# Current error rate: 0.1%
#
# Batch 10881 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10886 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10891 processed in 1.7 seconds
# Current error rate: 0.1%
#
# Batch 10896 processed in 1.5 seconds
# Current error rate: 0.1%
# Intermediate results saved at 109060 samples
#
# Batch 10901 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10906 processed in 1.6 seconds
# Current error rate: 0.1%
#
# Batch 10911 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10916 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10921 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10926 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10931 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10936 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10941 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10946 processed in 1.4 seconds
# Current error rate: 0.1%
#
# Batch 10951 processed in 1.6 seconds
# Current error rate: 0.1%
#
# Batch 10956 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10961 processed in 1.5 seconds
# Current error rate: 0.1%
#
# Batch 10966 processed in 1.6 seconds
# Current error rate: 0.1%
#
# Error processing batch starting at index 109690: Length of values (109751) does not match length of index (109691)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 126
#     123 df = pd.read_csv('final.csv')
#     125 # Process all samples (adjust batch size as needed)
# --> 126 results_df = process_large_dataset(
#     127     df,
#     128     categories,
#     129     batch_size=10,  # Use a small batch size to avoid memory issues
#     130     total_samples=len(df)  # Process all 100,000+ rows
#     131 )
#     133 # Save the final results to CSV
#     134 results_df.to_csv('philosophy_classifications_full.csv', index=False)
#
# Cell In[4], line 106, in process_large_dataset(df, categories, batch_size, total_samples)
#     104 # Create results dataframe with only the processed rows
#     105 df_results = df_subset.iloc[:len(all_predictions)].copy()
# --> 106 df_results['predicted_category'] = all_predictions
#     107 df_results['confidence'] = all_confidences
#     109 # Calculate and display summary statistics
#
# File ~/Desktop/phil_latest/bertopic_env/lib/python3.11/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/Desktop/phil_latest/bertopic_env/lib/python3.11/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/Desktop/phil_latest/bertopic_env/lib/python3.11/site-packages/pandas/core/frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~/Desktop/phil_latest/bertopic_env/lib/python3.11/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (109752) does not match length of index (109691)
